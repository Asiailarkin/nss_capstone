# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# #API for data

# %%
endpoint = 'https://api.fda.gov/food/event.json'

# %% [markdown]
# Read in 2v of CSV

# %%
df = pd.read_csv(r"c:\Users\16159\Documents\nss_da\projects\nss_capstone\data\caers_v2.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    report_number  \
# 0           0  2022-CFS-012051
# 1           1  2022-CFS-014209
# 2           2  2022-CFS-012981
# 3           3  2022-CFS-013319
# 4           4  2022-CFS-015815
#
#                                             outcomes date_created  \
# 0  ['Death', 'Hospitalization', 'Other Serious or...   2021-12-14
# 1       ['Other Serious or Important Medical Event']   2022-09-20
# 2       ['Other Serious or Important Medical Event']   2021-12-28
# 3  ['Death', 'Other Serious or Important Medical ...   2021-12-30
# 4                                  ['Other Outcome']   2022-11-02
#
#                                            reactions  date_started  \
# 0  ['Death', 'Ovarian cancer stage III', 'Uterine...    20080730.0
# 1        ['Disability', 'Euphoric mood', 'Paranoia']    20220916.0
# 2                          ['Fallopian tube cancer']    20160809.0
# 3                    ['Death', 'Endometrial cancer']    20080313.0
# 4        ['Erythema', 'Pruritus', 'Skin irritation']    20211029.0
#
#                                             products consumer.gender  \
# 0  [{'role': 'SUSPECT', 'name_brand': 'EXEMPTION ...          Female
# 1  [{'role': 'SUSPECT', 'name_brand': 'MYSTIC LAB...          Female
# 2  [{'role': 'SUSPECT', 'name_brand': 'EXEMPTION ...          Female
# 3  [{'role': 'SUSPECT', 'name_brand': 'EXEMPTION ...          Female
# 4  [{'role': 'SUSPECT', 'name_brand': 'DOVE VOLUM...          Female
#
#    consumer.age consumer.age_unit  year_created     role  \
# 0          65.0           year(s)          2021  SUSPECT
# 1          37.0           year(s)          2022  SUSPECT
# 2          56.0           year(s)          2021  SUSPECT
# 3          58.0           year(s)          2021  SUSPECT
# 4          27.5           year(s)          2022  SUSPECT
#
#                                  name_brand industry_code  \
# 0                               EXEMPTION 4            53
# 1  MYSTIC LABS COSMIC PEACH DELTA 8 GUMMIES            33
# 2                               EXEMPTION 4            53
# 3                               EXEMPTION 4            53
# 4      DOVE VOLUME AND FULLNESS DRY SHAMPOO            53
#
#                      industry_name
# 0                        Cosmetics
# 1  Candy W/O Choc/Special/Chew Gum
# 2                        Cosmetics
# 3                        Cosmetics
# 4                        Cosmetics

# %%
#Data types

print(df.dtypes)
# Out:
# Unnamed: 0             int64
# report_number         object
# outcomes              object
# date_created          object
# reactions             object
# date_started         float64
# products              object
# consumer.gender       object
# consumer.age         float64
# consumer.age_unit     object
# year_created           int64
# role                  object
# name_brand            object
# industry_code         object
# industry_name         object
# dtype: object

# %%
#How much data

print(df.shape)
# Out:
# (49743, 15)

# %%
unique_industries = df['industry_name'].unique()
for industry in unique_industries:
    print(industry)
# Out:
# Cosmetics
# Candy W/O Choc/Special/Chew Gum
# Vit/Min/Prot/Unconv Diet(Human/Animal)
# Ice Cream Prod
# Cereal Prep/Breakfast Food
# Nuts/Edible Seed
# Prep Salad Prod
# Soft Drink/Water
# Bakery Prod/Dough/Mix/Icing
# Fruit/Fruit Prod
# Whole Grain/Milled Grain Prod/Starch
# Soup
# Vegetables/Vegetable Products
# Dressing/Condiment
# Powder Formula
# Snack Food Item
# Mult Food Dinner/Grav/Sauce/Special
# Dietary Conventional Foods/Meal Replacements
# Filled Milk/Imit Milk Prod
# Macaroni/Noodle Prod
# Fishery/Seafood Prod
# Coffee/Tea
# Beverage Bases/Conc/Nectar
# Spices, Flavors And Salts
# Choc/Cocoa Prod
# Medical Foods, N.E.C.
# Food Additives (Human Use)
# Cheese/Cheese Prod
# Vegetable Protein Prod
# Ready to Serve Formula
# Baby Food Products
# Egg/Egg Prod
# Milk/Butter/Dried Milk Prod
# Meat, Meat Products and Poultry
# Gelatin/Rennet/Pudding Mix/Pie Filling
# Color Additiv Food/Drug/Cosmetic
# Vegetable Oils
# Alcoholic Beverage
# Food Sweeteners (Nutritive)
# Formula, Form Unspecified
# Miscellaneous Food Related Items
# Food Service/Conveyance
# Formula Raw Material
# Liquid Concentrate Formula

# %%
num_unique_industries = df['industry_name'].nunique()

print(num_unique_industries)
# Out:
# 44

# %%
filtered_df = df[df['consumer.age_unit'] == 'year(s)']
x = filtered_df['consumer.age'].astype(int) 
age_counts = x.value_counts().sort_index()

plt.bar(age_counts.index, age_counts.values, color='cornflowerblue', edgecolor='black')
plt.xlim(0, 125)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('')
plt.title('Reported Ages in Years through the Dataset')

plt.show()

# %%
age_counts = df[df['consumer.age_unit'] == 'year(s)']['consumer.age'].value_counts()

most_reported_age = age_counts.idxmax()
frequency = age_counts.max()

print("The most reported age is:", most_reported_age, "years")
print("It was reported", frequency, "times.")
# Out:
# The most reported age is: 60.0 years
# It was reported 844 times.

# %%
n = 5
filtered_df = df[df['consumer.age_unit'] == 'year(s)']
age_counts = filtered_df['consumer.age'].value_counts()

top_5_ages = age_counts.head(n).index.tolist()

print(top_5_ages)
# Out:
# [60.0, 57.0, 54.0, 53.0, 56.0]

# %%
max_age = df[df['consumer.age_unit'] == 'year(s)']['consumer.age'].max()
print(max_age)
# Out:
# 122.75

# %%
n = 5
filtered_df = df[df['consumer.age_unit'] == 'year(s)']
age_counts = filtered_df['consumer.age'].value_counts()

top_5_ages = age_counts.head(n)

print("Top 5 most frequent ages and their counts:")
for age, count in top_5_ages.items():
    print(f"Age: {age}, Count: {count}")
# Out:
# Top 5 most frequent ages and their counts:
# Age: 60.0, Count: 844
# Age: 57.0, Count: 832
# Age: 54.0, Count: 831
# Age: 53.0, Count: 794
# Age: 56.0, Count: 793

# %%
labels = df['consumer.gender'].value_counts().index
sizes = df['consumer.gender'].value_counts().values

total = sum(sizes)
percentages = [(size / total) * 100 for size in sizes]

fig, ax = plt.subplots(figsize=(10, 7))
wedges, _, autotexts = ax.pie(sizes, labels=None, autopct='', startangle=90)

legend_labels = [f'{label} ({percentage:.1f}%)' for label, percentage in zip(labels, percentages)]
ax.legend(wedges, legend_labels, title='Gender', loc='center left', bbox_to_anchor=(1, 0, 0.5, 1))

ax.set_title('Gender Reported from Reports')

plt.show()

# %%
frequency_of_appearances = df['industry_name'].value_counts()[:5].sort_values(ascending=False)

print(frequency_of_appearances)
# Out:
# industry_name
# Cosmetics                                 28592
# Vit/Min/Prot/Unconv Diet(Human/Animal)    11533
# Nuts/Edible Seed                           1892
# Vegetables/Vegetable Products              1042
# Cereal Prep/Breakfast Food                  789
# Name: count, dtype: int64

# %%
n = 5
top_5_industries = df['industry_name'].value_counts()[:n].index.tolist()

print(top_5_industries)
# Out:
# ['Cosmetics', 'Vit/Min/Prot/Unconv Diet(Human/Animal)', 'Nuts/Edible Seed', 'Vegetables/Vegetable Products', 'Cereal Prep/Breakfast Food']

# %%
import textwrap

fig = plt.figure(figsize=(10, 5))

wrapped_labels = [textwrap.fill(label, width=13) for label in top_5_industries]

bars = plt.bar(wrapped_labels, frequency_of_appearances, width=0.85, color='cornflowerblue', edgecolor='black')

plt.xlabel("Industries")
plt.ylabel("Times Appeared")

for bar, count in zip(bars, frequency_of_appearances):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
             '{:,}'.format(count), ha='center', va='bottom')
    
plt.tight_layout()
plt.show()

# %%
cosmetics_df = df[df['industry_name'] == 'Cosmetics']
n = 5
top_5_reactions = cosmetics_df['reactions'].value_counts().head(n)

wrapped_labels = [textwrap.fill(label, width=10) for label in top_5_reactions.index]

fig, ax = plt.subplots(figsize=(10, 5))
bars = top_5_reactions.plot(kind='bar', color='cornflowerblue', edgecolor='black')

plt.xlabel("Reactions")
plt.ylabel("")
plt.title("Top 5 Most Frequent Reactions in the Cosmetics Industry")
plt.xticks(range(len(wrapped_labels)), wrapped_labels, rotation=0, ha='center')  # Horizontal labels

for bar, count in zip(bars.patches, top_5_reactions):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
             '{:,}'.format(count), ha='center', va='bottom')

plt.show()

# %%
print(top_5_reactions)
# Out:
# reactions
# ['Ovarian cancer']              6464
# ['Death', 'Injury']             5072
# ['Ovarian cancer stage I']      1721
# ['Death', 'Ovarian cancer']     1638
# ['Ovarian cancer stage III']    1358
# Name: count, dtype: int64

# %%
cosmetics_df = df[df['industry_name'] == 'Cosmetics']

gender_distribution = cosmetics_df[cosmetics_df['consumer.gender'].isin(['Male', 'Female'])]['consumer.gender'].value_counts()

fig, ax = plt.subplots(figsize=(10, 7))
wedges, texts, autotexts = ax.pie(gender_distribution, labels=gender_distribution.index, autopct='', colors=['lightblue', 'lightcoral'])

ax.set_title('Genders Affected in Cosmetics Industry')

total = gender_distribution.sum()
percentages = [(count / total) * 100 for count in gender_distribution]

legend_labels = [f'{label} ({percentage:.1f}%)' for label, percentage in zip(gender_distribution.index, percentages)]
ax.legend(wedges, legend_labels, title='Gender', loc='center left', bbox_to_anchor=(1, 0, 0.5, 1))

plt.show()

# %%
cosmetics_ovarian_df = df[(df['industry_name'] == 'Cosmetics') & (df['reactions'] == "['Ovarian cancer']")]
top_brands = cosmetics_ovarian_df['name_brand'].value_counts().head(3)

print("Top 3 brands in the Cosmetics industry causing Ovarian cancer:")
print(top_brands)
# Out:
# Top 3 brands in the Cosmetics industry causing Ovarian cancer:
# name_brand
# EXEMPTION 4                6106
# JOHNSONS POWDER NO UPC      356
# SHOWER TO SHOWER NO UPC       2
# Name: count, dtype: int64

# %%
cosmetics_ovarian_df = df[(df['industry_name'] == 'Cosmetics') & (df['reactions'] == "['Death', 'Injury']")]
top_brands = cosmetics_ovarian_df['name_brand'].value_counts().head(3)

print("Top 3 brands in the Cosmetics industry causing Ovarian cancer:")
print(top_brands)
# Out:
# Top 3 brands in the Cosmetics industry causing Ovarian cancer:
# name_brand
# EXEMPTION 4                4951
# JOHNSONS POWDER NO UPC      120
# SHOWER TO SHOWER NO UPC       1
# Name: count, dtype: int64

# %%
cosmetics_df = df[df['industry_name'] == 'Cosmetics']
top_5_brands = cosmetics_df['name_brand'].value_counts().head(5)

print("Top 5 name brands and their counts in the Cosmetics industry:")
print(top_5_brands)
# Out:
# Top 5 name brands and their counts in the Cosmetics industry:
# name_brand
# EXEMPTION 4               23253
# JOHNSONS POWDER NO UPC     1717
# DEVACURL                     53
# DOVE DRY SHAMPOO             41
# EOS LIP BALM                 40
# Name: count, dtype: int64

# %%
cosmetics_df = df[df['industry_name'] == 'Cosmetics']
top_5_brands = cosmetics_df['name_brand'].value_counts().head(5)

wrapped_labels = [textwrap.fill(label, width=10) for label in top_5_brands.index]

fig, ax = plt.subplots(figsize=(10, 5))
bars = top_5_brands.plot(kind='bar', color='cornflowerblue', edgecolor='black')

plt.xlabel("Name Brands")
plt.ylabel(" ")
plt.title("Top 5 Name Brands in the Cosmetics Industry")
plt.xticks(range(len(wrapped_labels)), wrapped_labels, rotation=0, ha='center')  # Horizontal labels

for bar, count in zip(bars.patches, top_5_brands):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
             '{:,}'.format(count), ha='center', va='bottom')

plt.show()

# %%
df['date_created'] = pd.to_datetime(df['date_created'])

max_reports_per_month = df.groupby(df['date_created'].dt.to_period("M"))['report_number'].count()

x_labels = max_reports_per_month.index[::2].astype(str)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(max_reports_per_month.index.astype(str), max_reports_per_month.values, marker='o', linestyle='-', color='cornflowerblue')

plt.xlabel("Date")
plt.ylabel(" ")
plt.title("Reports Per Month Over Time")
plt.xticks(x_labels, rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()  
plt.show()

# %%
df['date_created'] = pd.to_datetime(df['date_created'])

reports_per_date = df.groupby(df['date_created'].dt.date)['report_number'].count()

date_with_max_reports = reports_per_date.idxmax()

max_reports = reports_per_date.max()

print(f"The date with the maximum number of adverse events is {date_with_max_reports} with {max_reports} reports.")
# Out:
# The date with the maximum number of adverse events is 2022-05-23 with 825 reports.

# %%
df.head()
# Out:
#    Unnamed: 0    report_number  \
# 0           0  2022-CFS-012051
# 1           1  2022-CFS-014209
# 2           2  2022-CFS-012981
# 3           3  2022-CFS-013319
# 4           4  2022-CFS-015815
#
#                                             outcomes date_created  \
# 0  ['Death', 'Hospitalization', 'Other Serious or...   2021-12-14
# 1       ['Other Serious or Important Medical Event']   2022-09-20
# 2       ['Other Serious or Important Medical Event']   2021-12-28
# 3  ['Death', 'Other Serious or Important Medical ...   2021-12-30
# 4                                  ['Other Outcome']   2022-11-02
#
#                                            reactions  date_started  \
# 0  ['Death', 'Ovarian cancer stage III', 'Uterine...    20080730.0
# 1        ['Disability', 'Euphoric mood', 'Paranoia']    20220916.0
# 2                          ['Fallopian tube cancer']    20160809.0
# 3                    ['Death', 'Endometrial cancer']    20080313.0
# 4        ['Erythema', 'Pruritus', 'Skin irritation']    20211029.0
#
#                                             products consumer.gender  \
# 0  [{'role': 'SUSPECT', 'name_brand': 'EXEMPTION ...          Female
# 1  [{'role': 'SUSPECT', 'name_brand': 'MYSTIC LAB...          Female
# 2  [{'role': 'SUSPECT', 'name_brand': 'EXEMPTION ...          Female
# 3  [{'role': 'SUSPECT', 'name_brand': 'EXEMPTION ...          Female
# 4  [{'role': 'SUSPECT', 'name_brand': 'DOVE VOLUM...          Female
#
#    consumer.age consumer.age_unit  year_created     role  \
# 0          65.0           year(s)          2021  SUSPECT
# 1          37.0           year(s)          2022  SUSPECT
# 2          56.0           year(s)          2021  SUSPECT
# 3          58.0           year(s)          2021  SUSPECT
# 4          27.5           year(s)          2022  SUSPECT
#
#                                  name_brand industry_code  \
# 0                               EXEMPTION 4            53
# 1  MYSTIC LABS COSMIC PEACH DELTA 8 GUMMIES            33
# 2                               EXEMPTION 4            53
# 3                               EXEMPTION 4            53
# 4      DOVE VOLUME AND FULLNESS DRY SHAMPOO            53
#
#                      industry_name
# 0                        Cosmetics
# 1  Candy W/O Choc/Special/Chew Gum
# 2                        Cosmetics
# 3                        Cosmetics
# 4                        Cosmetics

# %%
filtered_df = df[df['consumer.age_unit'].isin(['day(s)', 'week(s)', 'month(s)'])]
industry_counts = filtered_df['industry_name'].value_counts()

top_10_industries = industry_counts.head(10)


print("Top 10 Industries affecting those reporting age in days, weeks, or months:")
print(top_10_industries)
# Out:
# Top 10 Industries affecting those reporting age in days, weeks, or months:
# industry_name
# Powder Formula                                  422
# Vit/Min/Prot/Unconv Diet(Human/Animal)           99
# Cosmetics                                        65
# Baby Food Products                               42
# Nuts/Edible Seed                                 23
# Ready to Serve Formula                           22
# Cereal Prep/Breakfast Food                       17
# Milk/Butter/Dried Milk Prod                      10
# Bakery Prod/Dough/Mix/Icing                       8
# Dietary Conventional Foods/Meal Replacements      8
# Name: count, dtype: int64

# %%
# Out:
# Number of Reports for Each Industry Affecting Children:
# Series([], Name: count, dtype: int64)

# %%
filtered_df = df[df['consumer.age_unit'].isin(['day(s)', 'week(s)', 'month(s)'])]
industry_counts = filtered_df['industry_name'].value_counts()
top_5_industries = industry_counts.head(5)
plt.figure(figsize=(10, 6))
bars = plt.bar(range(len(top_5_industries)), top_5_industries, color='cornflowerblue', edgecolor='black')

plt.xticks(range(len(top_5_industries)), [textwrap.fill(label, 15) for label in top_5_industries.index], rotation=0)

plt.title('Top 5 Industries affecting Children')
plt.xlabel('Industry')
plt.ylabel('')

# Attach text labels above each bar displaying its value
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval, round(yval, 2), va='bottom')

plt.tight_layout()  # Ensure tight layout to prevent clipping of labels
plt.show()

# %%
powder_formula_df = df[df['industry_name'] == 'Powder Formula'].copy()
powder_formula_df['date_created'] = pd.to_datetime(powder_formula_df['date_created'])

max_reports_per_month_powder_formula = powder_formula_df.groupby(powder_formula_df['date_created'].dt.to_period("M"))['report_number'].count()

plt.figure(figsize=(12, 6))
max_reports_per_month_powder_formula.plot(kind='line', color='cornflowerblue', marker='o')

plt.title('Adverse Events in Powder Formula Over Time')
plt.xlabel('Month-Year')
plt.ylabel('')
plt.grid(True)
plt.show()

# %%
powder_formula_df = df[df['industry_name'] == 'Powder Formula'].copy()
powder_formula_df['date_created'] = pd.to_datetime(powder_formula_df['date_created'])
max_year_powder_formula = powder_formula_df['date_created'].dt.year.max()

print(f"The maximum year for reports in the Powder Formula industry is: {max_year_powder_formula}")
# Out:
# The maximum year for reports in the Powder Formula industry is: 2023

# %%
df['age_category'] = pd.cut(df['consumer.age'], bins=[0, 17, float('inf')], labels=['Children', 'Adults'], right=False)
age_category_counts = df['age_category'].value_counts()
percentages = age_category_counts / age_category_counts.sum() * 100
colors = ['cornflowerblue', 'gold']

plt.figure(figsize=(8, 8))
plt.pie(age_category_counts, labels=None, autopct=None, startangle=90, colors=colors)

legend_labels = [f'{label} ({percent:.1f}%)' for label, percent in zip(age_category_counts.index, percentages)]
plt.legend(labels=legend_labels, loc='upper right', bbox_to_anchor=(1, 1), title='Age Category', borderaxespad=0.)

plt.title('Percentage of those Affected by Age')
plt.show()

# %%
powdered_formula_df = df[df['industry_name'] == 'Powder Formula']
top_5_brands = powder_formula_df['name_brand'].value_counts().head(5)

wrapped_labels = [textwrap.fill(label, width=10) for label in top_5_brands.index]

fig, ax = plt.subplots(figsize=(10, 5))
bars = top_5_brands.plot(kind='bar', color='cornflowerblue', edgecolor='black')

plt.xlabel("Brands")
plt.ylabel(" ")
plt.title("Most Dangerous Formula")
plt.xticks(range(len(wrapped_labels)), wrapped_labels, rotation=0, ha='center')  # Horizontal labels

for bar, count in zip(bars.patches, top_5_brands):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
             '{:,}'.format(count), ha='center', va='bottom')

plt.show()

# %%
df['date_created'] = pd.to_datetime(df['date_created'])
reports_per_month = df.groupby(df['date_created'].dt.to_period("M"))['report_number'].count()
average_reports_per_month = reports_per_month.mean()

print(f"The average number of reports per month throughout the dataset is: {average_reports_per_month:.2f}")
# Out:
# The average number of reports per month throughout the dataset is: 872.68
